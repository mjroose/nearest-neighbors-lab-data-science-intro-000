# %% [markdown]
# # Nearest Neighbors Lab

# %% [markdown]
# ### Introduction
#
# In this lab, you apply nearest neighbors technique to help a taxi company predict the length of their rides.  Imagine that we are hired to consult for LiftOff, a limo and taxi service that is just opening up in NYC.  Liftoff wants it's taxi drivers to target longer rides, as the longer the ride the more money it makes.  LiftOff has the following theory:
#
# * the pickup location of a taxi ride can help predict the length of the ride.
#
#
#
# LiftOff asks us to do some analysis to write a function that will allow it to **predict the length of a taxi ride for any given location **.
#
# Our technique will be the following:
#   * **Collect** Obtain the data containing all of the taxi information, and only select the attributes of taxi trips that we need
#   * ** Explore ** Examine the attributes of our data, and plot some of our data on a map
#   * ** Train ** Write our nearest neighbors formula, and change the number of nearby trips to predict the length of a new trip
#   * ** Predict ** Use our function to predict trip lengths of new locations

# %% [markdown]
# ### Collect and Explore the data

# %% [markdown]
# #### Collect the Data

# %% [markdown]
# Luckily for us, [NYC Open Data](https://opendata.cityofnewyork.us/) collects information about NYC taxi trips and provides this data on [its website](https://data.cityofnewyork.us/Transportation/2014-Yellow-Taxi-Trip-Data/gn7m-em8n).

# %% [markdown]
# ![](./nyc-taxi.png)

# %% [markdown]
# For your reading pleasure, the data has already been downloaded into the [trips.json](https://github.com/learn-co-curriculum/nearest-neighbors-lab/blob/master/trips.json) file in this lab which you can find here.  We'll use Python's `json` library to take the data from the `trips.json` file and store it as a variable in our notebook.

# %%
import json
# First, read the file
trips_file = open('trips.json')
# Then, convert contents to list of dictionaries 
trips = json.load(trips_file)

# %% [markdown]
# > Press shift + enter

# %% [markdown]
# #### Explore the data

# %% [markdown]
# The next step is to explore the data.  First, let's see how many trips we have.

# %%
len(trips)
# Out:
# 1000

# %% [markdown]
# Not bad at all.  Now let's see what each individual trip looks like.  Each trip is a dictionary, so we can see the attributes of each trip with the `keys` function.

# %%
trips[0].keys()
# Out:
# dict_keys(['dropoff_datetime', 'dropoff_latitude', 'dropoff_longitude', 'fare_amount', 'imp_surcharge', 'mta_tax', 'passenger_count', 'payment_type', 'pickup_datetime', 'pickup_latitude', 'pickup_longitude', 'rate_code', 'tip_amount', 'tolls_amount', 'total_amount', 'trip_distance', 'vendor_id'])

# %% [markdown]
# #### Limit our data

# %% [markdown]
# Ok, now that we have explored some of our data, let's begin to think through what data is relevant for our task.

# %% [markdown]
# Remember that our task is to **use the trip location to predict the length of a trip**.  So let's select the `pickup_latitude`, `pickup_longitude`, and `trip_distance` from each trip.  That will give us the trip location and related `trip_distance` for each trip.  Then based on these **actual** trip distances we can use nearest neighbors to predict an **expected** trip distance for a trip, provided an **actual** location.

# %% [markdown]
# ** Add in about trip distance **

# %% [markdown]
# Write a function called `parse_trips(trips)` that returns a list of the trips with only the following attributes:
# * `trip_distance`
# * `pickup_latitude`
# * `pickup_longitude`

# %%
def parse_trips(trips):
    scrubbed_trips = []
    for trip in trips:
        scrubbed_trip = {}
        scrubbed_trip['trip_distance'] = trip['trip_distance']
        scrubbed_trip['pickup_latitude'] = trip['pickup_latitude']
        scrubbed_trip['pickup_longitude'] = trip ['pickup_longitude']
        scrubbed_trips.append(scrubbed_trip)
    return scrubbed_trips

# %%
parsed_trips = parse_trips(trips)
parsed_trips and parsed_trips[0]

# {'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.78115',
#  'trip_distance': '18.38'}
# Out:
# {'trip_distance': '18.379999999999999',
#  'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.781149999999997'}

# %% [markdown]
# Now, there's just one change to make.  If you look at one of the trips, all of the values are strings.  Let's change them to be floats.

# %%
def float_values(trips):
    typed_trips = []
    for trip in trips:
        trip['trip_distance'] = float(trip['trip_distance'])
        trip['pickup_latitude'] = float(trip['pickup_latitude'])
        trip['pickup_longitude'] = float(trip['pickup_longitude'])
        typed_trips.append(trip)
    return typed_trips

# %%
cleaned_trips = float_values(parsed_trips)

# %%
cleaned_trips[0]

# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}
# Out:
# {'trip_distance': 18.38,
#  'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115}

# %% [markdown]
# ### Exploring the Data

# %% [markdown]
# Now that we have paired down our data, let's get a sense of our trip data.  We can use the `folium` Python library to plot a map of Manhattan, and our data.  First we must import `folium`, and then use the `Map` function to pass through a `location`, and `zoom_start`.  If a map isn't showing up below, copy and paste the command `pip install -r requirements.txt` into your terminal to install `folium` then try again.

# %%
import folium
manhattan_map = folium.Map(location=[40.7589, -73.9851], zoom_start=11)

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok, now let's see how we could add a dot to mark a specific location.  We'll start with Times Square.

# %%
marker = folium.CircleMarker(location = [40.7589, -73.9851], radius=10)
marker.add_to(manhattan_map)

# %% [markdown]
# Above, we first create a marker.  Then we add that circle marker to the `manhattan_map` we created earlier.

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Do you see that blue dot near Time's Square?  That is our marker.
#
# So now that we can plot one marker on a map, we should have a sense of how we can plot many markers on a map to display our taxi ride data.  We simply plot a map, and then we add a marker for each location of a taxi trip.
#
# Now let's write some functions to allow us to plot maps and add markers a little more easily.

# %% [markdown]
# #### Writing some map plotting functions

# %% [markdown]
# As a first step towards this, note that the functions to create both a marker and map each take in a location as two element list, representing the latitude and longitude values.  Take another look:
#
# ```python
# marker = folium.CircleMarker(location = [40.7589, -73.9851])
# manhattan_map = folium.Map(location=[40.7589, -73.9851])
# ```
#
# So let's write a function called to create this two element list from a trip.  Write a function called `location` that  takes in a trip as an argument and returns a list where the first element is the latitude and the second is the longitude.  Remember that a location looks like the following:

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115,  'trip_distance': 18.38}
first_trip
# Out:
# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}

# %%
def location(trip):
    return [trip['pickup_latitude'], trip['pickup_longitude']]

# %%
first_location = location(first_trip) # [40.64499, -73.78115]
first_location # [40.64499, -73.78115]
# Out:
# [40.64499, -73.78115]

# %% [markdown]
# Ok, now that we can turn a trip into a location, let's turn a location into a marker.  Write a function called `to_marker` that takes in a location (in the form of a list) as an argument, and returns a folium `circleMarker` for that location.  The radius of the marker should always equal 6.

# %%
def to_marker(location):
    marker = folium.CircleMarker(location = location, radius = 6)
    return marker

# %%
import json
times_square_marker = to_marker([40.7589, -73.9851])

times_square_marker and times_square_marker.location # [40.7589, -73.9851]
times_square_marker and json.loads(times_square_marker.options)['radius'] # 6
# Out:
# 6

# %% [markdown]
# Ok, now that we know how to produce a single marker, let's write a function to produce lots.  We can write a function called `markers_from_trips` that takes in a list of trips, and returns a marker object for each trip.

# %%
def markers_from_trips(trips):
    markers_list = list(map(lambda trip: to_marker(location(trip)), trips))
    return markers_list

# %%
trip_markers = markers_from_trips(cleaned_trips)

# %%
cleaned_trips[0:4]
# Out:
# [{'trip_distance': 18.38,
#   'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049}]

# %%
trip_markers and len(trip_markers) # 1000

list(map(lambda marker: marker.location, trip_markers[0:4]))
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]
# Out:
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]

# %% [markdown]
# Ok, now that we have a function that creates locations, and a function that creates markers, it is time to write a function to plot a map.
#
# Write a function called `map_from` that, provided the first argument of a list location and second argument an integer representing the `zoom_start`, returns a `folium` map the corresponding location and `zoom_start` attributes.
#
# > Hint: The following is how to write a map with folium:
# > ```python
#     folium.Map(location=location, zoom_start=zoom_amount)
# > ```

# %%
def map_from(location, zoom_amount):
    return folium.Map(location=location, zoom_start=zoom_amount)

# %%
times_square_map = map_from([40.7589, -73.9851], 15)
times_square_map and times_square_map.location # [40.7589, -73.9851]
times_square_map and times_square_map.zoom_start # 15
# Out:
# 15

# %%
times_square_marker and times_square_marker.add_to(times_square_map)
times_square_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have a marker and a map, now let's write a function that adds a lot of markers to a map.

# %%
manhattan_map = map_from([40.7589, -73.9851], 13)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def add_markers(markers, map_obj):
    for marker in markers:
        marker.add_to(map_obj)
    return map_obj

# %%
map_with_markers = add_markers(trip_markers, manhattan_map)

# %%
map_with_markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Using Nearest Neighbors

# %% [markdown]
# Ok, let's write a function that given a latitude and longitude will predict the distance for us.  We'll do this by first finding the nearest trips given a latitude and longitude.

# %% [markdown]
# Here we once again apply the nearest neighbors formula. As a first step, write a function named `distance_location` that calculates the distance in pickup location between two trips.

# %%
import math

def distance_location(selected_trip, neighbor_trip):
    x = abs(selected_trip['pickup_latitude'] - neighbor_trip['pickup_latitude'])
    y = abs(selected_trip['pickup_longitude'] - neighbor_trip['pickup_longitude'])
    distance = math.sqrt(x**2 + y**2)
    return distance

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}
second_trip = {'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098, 'trip_distance': 1.3}
distance_first_and_second = distance_location(first_trip, second_trip)

distance_first_and_second and round(distance_first_and_second, 3) # 0.235
# Out:
# 0.235

# %% [markdown]
# Ok, next write a function called `distance_between_neighbors` that adds a new key-value pair, called `distance_from_selected`, that calculates the distance of the `neighbor_trip` from the `selected_trip`.

# %%
def distance_between_neighbors(selected_trip, neighbor_trip):
    distance_from_selected = distance_location(selected_trip, neighbor_trip)
    neighbor_trip['distance_from_selected'] = distance_from_selected
    return neighbor_trip

# %%
distance_between_neighbors(first_trip, second_trip)

# {'distance_from_selected': 0.23505256047318146,
#  'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 1.3}
# Out:
# {'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 1.3,
#  'distance_from_selected': 0.23505256047318146}

# %% [markdown]
# Ok, now our `neighbor_trip` has another attribute called `distance_from_selected`, that indicates the distance from the `neighbor_trip`'s pickup location from the `selected_trip`.

# %% [markdown]
# > ** Understand the data:** Our dictionary now has a few attributes, two of which say distance.  Let's make sure we understand the difference.
# > * **`distance_from_selected`:** This is our calculation of the distance of the neighbor's pickup location from the selected trip.
# > * **`trip_distance`:** This is the attribute we were provided initially.  It tells us the length of the neighbor's taxi trip from pickup to drop-off.

# %% [markdown]
# Next, write a function called `distance_all` that provided a list of neighbors, returns each of those neighbors with their respective `distance_from_selected` numbers.

# %%
def distance_all(selected_individual, neighbors):
    neighbors_with_distance_from_selected = []
    unselected_neighbors = list(filter(lambda neighbor: neighbor['pickup_latitude'] != selected_individual['pickup_latitude'] and neighbor['pickup_longitude'] != selected_individual['pickup_longitude'], neighbors))
    for neighbor in unselected_neighbors:
        neighbor = distance_between_neighbors(selected_individual, neighbor)
    return unselected_neighbors

# %%
cleaned_trips and distance_all(first_trip, cleaned_trips[0:4])
# Out:
# [{'trip_distance': 1.3,
#   'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098,
#   'distance_from_selected': 0.23505256047318146},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902,
#   'distance_from_selected': 0.2162779533470808},
#  {'trip_distance': 2.4,
#   'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049,
#   'distance_from_selected': 0.24242215976473674}]

# %% [markdown]
# Now write the nearest neighbors formula to calculate the distance of the `selected_trip` from all of the `cleaned_trips` in our dataset.  If no number is provided, it should return the top 3 neighbors.

# %%
def nearest_neighbors(selected_trip, trips, number = 3):
    if not number:
        number = len(trips) - 1
    unsorted_neighbors = distance_all(selected_trip, trips)
    sorted_neighbors = sorted(unsorted_neighbors, key=lambda neighbor: neighbor['distance_from_selected'])
    return sorted_neighbors

# %%
new_trip = {'pickup_latitude': 40.64499,
'pickup_longitude': -73.78115,
'trip_distance': 18.38}

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
nearest_three_neighbors
# [{'distance_from_individual': 0.0004569288784918792,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78},
#  {'distance_from_individual': 0.0011292165425673159,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7},
#  {'distance_from_individual': 0.0042359798158141185,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3}]
# Out:
# [{'trip_distance': 7.78,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'distance_from_selected': 0.0004569288784918792},
#  {'trip_distance': 12.7,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'distance_from_selected': 0.0011292165425673159},
#  {'trip_distance': 17.3,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'distance_from_selected': 0.0042359798158141185},
#  {'trip_distance': 17.5,
#   'pickup_latitude': 40.645316,
#   'pickup_longitude': -73.776808,
#   'distance_from_selected': 0.004354220940644754},
#  {'trip_distance': 20.5,
#   'pickup_latitude': 40.645718,
#   'pickup_longitude': -73.776765,
#   'distance_from_selected': 0.004445020697364217},
#  {'trip_distance': 21.44,
#   'pickup_latitude': 40.64534,
#   'pickup_longitude': -73.77668,
#   'distance_from_selected': 0.004483681523031949},
#  {'trip_distance': 19.05,
#   'pickup_latitude': 40.645322,
#   'pickup_longitude': -73.776652,
#   'distance_from_selected': 0.0045102359140052955},
#  {'trip_distance': 16.79,
#   'pickup_latitude': 40.646587,
#   'pickup_longitude': -73.78582,
#   'distance_from_selected': 0.004935515069375294},
#  {'trip_distance': 18.2,
#   'pickup_latitude': 40.648605,
#   'pickup_longitude': -73.78482,
#   'distance_from_selected': 0.005151419707228516},
#  {'trip_distance': 16.63,
#   'pickup_latitude': 40.641805,
#   'pickup_longitude': -73.78641,
#   'distance_from_selected': 0.006149132052581531},
#  {'trip_distance': 24.55,
#   'pickup_latitude': 40.642817,
#   'pickup_longitude': -73.788912,
#   'distance_from_selected': 0.008060432556630562},
#  {'trip_distance': 19.03,
#   'pickup_latitude': 40.643172,
#   'pickup_longitude': -73.789035,
#   'distance_from_selected': 0.008091869314319596},
#  {'trip_distance': 11.5,
#   'pickup_latitude': 40.641375,
#   'pickup_longitude': -73.788935,
#   'distance_from_selected': 0.008583382200508133},
#  {'trip_distance': 23.7,
#   'pickup_latitude': 40.644032,
#   'pickup_longitude': -73.790294,
#   'distance_from_selected': 0.009194046987051402},
#  {'trip_distance': 18.5,
#   'pickup_latitude': 40.642527,
#   'pickup_longitude': -73.791427,
#   'distance_from_selected': 0.01056802242617023},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.649679,
#   'pickup_longitude': -73.804526,
#   'distance_from_selected': 0.02384164627285503},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.721951,
#   'pickup_longitude': -73.844435,
#   'distance_from_selected': 0.09963928314676157},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.748042,
#   'pickup_longitude': -73.880385,
#   'distance_from_selected': 0.1430639714568314},
#  {'trip_distance': 1.52,
#   'pickup_latitude': 40.747252,
#   'pickup_longitude': -73.888215,
#   'distance_from_selected': 0.14805549928659145},
#  {'trip_distance': 12.15,
#   'pickup_latitude': 40.768787,
#   'pickup_longitude': -73.862845,
#   'distance_from_selected': 0.14832319519886364},
#  {'trip_distance': 11.2,
#   'pickup_latitude': 40.769112,
#   'pickup_longitude': -73.862679,
#   'distance_from_selected': 0.14850336267236677},
#  {'trip_distance': 12.55,
#   'pickup_latitude': 40.77012,
#   'pickup_longitude': -73.86361,
#   'distance_from_selected': 0.14985716032275284},
#  {'trip_distance': 5.09,
#   'pickup_latitude': 40.769887,
#   'pickup_longitude': -73.86443,
#   'distance_from_selected': 0.15011601849569428},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.755756,
#   'pickup_longitude': -73.884413,
#   'distance_from_selected': 0.15143432214989852},
#  {'trip_distance': 9.61,
#   'pickup_latitude': 40.771097,
#   'pickup_longitude': -73.865913,
#   'distance_from_selected': 0.15194650906816182},
#  {'trip_distance': 2.55,
#   'pickup_latitude': 40.770932,
#   'pickup_longitude': -73.86622,
#   'distance_from_selected': 0.15198122339289416},
#  {'trip_distance': 8.7,
#   'pickup_latitude': 40.773595,
#   'pickup_longitude': -73.870591,
#   'distance_from_selected': 0.15664909353712037},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.77365,
#   'pickup_longitude': -73.870572,
#   'distance_from_selected': 0.1566834058986488},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.773602,
#   'pickup_longitude': -73.871055,
#   'distance_from_selected': 0.15692022039558665},
#  {'trip_distance': 10.33,
#   'pickup_latitude': 40.773777,
#   'pickup_longitude': -73.870957,
#   'distance_from_selected': 0.15700760687941853},
#  {'trip_distance': 22.8,
#   'pickup_latitude': 40.773797,
#   'pickup_longitude': -73.871065,
#   'distance_from_selected': 0.15708580608699615},
#  {'trip_distance': 8.73,
#   'pickup_latitude': 40.773907,
#   'pickup_longitude': -73.871275,
#   'distance_from_selected': 0.15729624443705073},
#  {'trip_distance': 8.12,
#   'pickup_latitude': 40.773952,
#   'pickup_longitude': -73.871235,
#   'distance_from_selected': 0.15731021794213085},
#  {'trip_distance': 0.98,
#   'pickup_latitude': 40.750027,
#   'pickup_longitude': -73.89876,
#   'distance_from_selected': 0.1576860281350266},
#  {'trip_distance': 12.06,
#   'pickup_latitude': 40.771472,
#   'pickup_longitude': -73.8755,
#   'distance_from_selected': 0.15779613057360375},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.774453,
#   'pickup_longitude': -73.872166,
#   'distance_from_selected': 0.1582547965307915},
#  {'trip_distance': 8.86,
#   'pickup_latitude': 40.774487,
#   'pickup_longitude': -73.872417,
#   'distance_from_selected': 0.15842707564681147},
#  {'trip_distance': 9.21,
#   'pickup_latitude': 40.77409,
#   'pickup_longitude': -73.87317,
#   'distance_from_selected': 0.15853860854694424},
#  {'trip_distance': 6.54,
#   'pickup_latitude': 40.774152,
#   'pickup_longitude': -73.873092,
#   'distance_from_selected': 0.15854385389538378},
#  {'trip_distance': 7.65,
#   'pickup_latitude': 40.77408,
#   'pickup_longitude': -73.874527,
#   'distance_from_selected': 0.15932197660398323},
#  {'trip_distance': 8.4,
#   'pickup_latitude': 40.77403,
#   'pickup_longitude': -73.874597,
#   'distance_from_selected': 0.15932251381710127},
#  {'trip_distance': 9.25,
#   'pickup_latitude': 40.774087,
#   'pickup_longitude': -73.874592,
#   'distance_from_selected': 0.1593657515685297},
#  {'trip_distance': 9.37,
#   'pickup_latitude': 40.77411,
#   'pickup_longitude': -73.874625,
#   'distance_from_selected': 0.15940373278251582},
#  {'trip_distance': 1.77,
#   'pickup_latitude': 40.76514,
#   'pickup_longitude': -73.886932,
#   'distance_from_selected': 0.16008077343641747},
#  {'trip_distance': 3.03,
#   'pickup_latitude': 40.702557,
#   'pickup_longitude': -73.93467,
#   'distance_from_selected': 0.1639583785263808},
#  {'trip_distance': 11.98,
#   'pickup_latitude': 40.772652,
#   'pickup_longitude': -73.885138,
#   'distance_from_selected': 0.16465445754063396},
#  {'trip_distance': 9.41,
#   'pickup_latitude': 40.77293,
#   'pickup_longitude': -73.88525,
#   'distance_from_selected': 0.16494075784960227},
#  {'trip_distance': 8.2,
#   'pickup_latitude': 40.773009,
#   'pickup_longitude': -73.885269,
#   'distance_from_selected': 0.16501403128825104},
#  {'trip_distance': 9.55,
#   'pickup_latitude': 40.773118,
#   'pickup_longitude': -73.885322,
#   'distance_from_selected': 0.16513203798173234},
#  {'trip_distance': 5.75,
#   'pickup_latitude': 40.708292,
#   'pickup_longitude': -73.939932,
#   'distance_from_selected': 0.17093527057924798},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.768497,
#   'pickup_longitude': -73.899785,
#   'distance_from_selected': 0.1712549043794084},
#  {'trip_distance': 8.26,
#   'pickup_latitude': 40.743475,
#   'pickup_longitude': -73.923155,
#   'distance_from_selected': 0.17281410605039918},
#  {'trip_distance': 3.6,
#   'pickup_latitude': 40.712097,
#   'pickup_longitude': -73.94075,
#   'distance_from_selected': 0.1731343681912959},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.707087,
#   'pickup_longitude': -73.94328,
#   'distance_from_selected': 0.17361501752153158},
#  {'trip_distance': 5.9,
#   'pickup_latitude': 40.712003,
#   'pickup_longitude': -73.945566,
#   'distance_from_selected': 0.1775481997233464},
#  {'trip_distance': 8.8,
#   'pickup_latitude': 40.711467,
#   'pickup_longitude': -73.945825,
#   'distance_from_selected': 0.17758673135682382},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.763835,
#   'pickup_longitude': -73.915012,
#   'distance_from_selected': 0.1790060587494237},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.713948,
#   'pickup_longitude': -73.951672,
#   'distance_from_selected': 0.18393737588647427},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.751801,
#   'pickup_longitude': -73.933138,
#   'distance_from_selected': 0.18576582534201758},
#  {'trip_distance': 14.43,
#   'pickup_latitude': 40.757037,
#   'pickup_longitude': -73.929485,
#   'distance_from_selected': 0.1858972900125233},
#  {'trip_distance': 3.08,
#   'pickup_latitude': 40.639542,
#   'pickup_longitude': -73.967915,
#   'distance_from_selected': 0.1868444431311863},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.763843,
#   'pickup_longitude': -73.928025,
#   'distance_from_selected': 0.18893994081189622},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.760289,
#   'pickup_longitude': -73.931531,
#   'distance_from_selected': 0.1894948668486909},
#  {'trip_distance': 1.56,
#   'pickup_latitude': 40.68078,
#   'pickup_longitude': -73.967735,
#   'distance_from_selected': 0.1899865424839425},
#  {'trip_distance': 7.04,
#   'pickup_latitude': 40.712612,
#   'pickup_longitude': -73.95882,
#   'distance_from_selected': 0.19010356068207196},
#  {'trip_distance': 7.1,
#   'pickup_latitude': 40.721519,
#   'pickup_longitude': -73.956165,
#   'distance_from_selected': 0.19101554404288879},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.715884,
#   'pickup_longitude': -73.959979,
#   'distance_from_selected': 0.19236883967265345},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.829557,
#   'pickup_longitude': -73.837699,
#   'distance_from_selected': 0.19303566222333352},
#  {'trip_distance': 1.66,
#   'pickup_latitude': 40.758215,
#   'pickup_longitude': -73.937667,
#   'distance_from_selected': 0.19317730693330024},
#  {'trip_distance': 10.72,
#   'pickup_latitude': 40.758277,
#   'pickup_longitude': -73.937715,
#   'distance_from_selected': 0.19325253838953863},
#  {'trip_distance': 2.38,
#   'pickup_latitude': 40.750687,
#   'pickup_longitude': -73.943522,
#   'distance_from_selected': 0.1937434442581256},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.68118,
#   'pickup_longitude': -73.980602,
#   'distance_from_selected': 0.20270869839255298},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.671487,
#   'pickup_longitude': -73.984354,
#   'distance_from_selected': 0.204924270463505},
#  {'trip_distance': 5.8,
#   'pickup_latitude': 40.691887,
#   'pickup_longitude': -73.982322,
#   'distance_from_selected': 0.20656597540011276},
#  {'trip_distance': 6.07,
#   'pickup_latitude': 40.68703,
#   'pickup_longitude': -73.98489,
#   'distance_from_selected': 0.20803208694814002},
#  {'trip_distance': 3.89,
#   'pickup_latitude': 40.694095,
#   'pickup_longitude': -73.9839,
#   'distance_from_selected': 0.2086117530845358},
#  {'trip_distance': 17.55,
#   'pickup_latitude': 40.766367,
#   'pickup_longitude': -73.952442,
#   'distance_from_selected': 0.20993647942414254},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.764276,
#   'pickup_longitude': -73.954283,
#   'distance_from_selected': 0.2102479143416244},
#  {'trip_distance': 2.27,
#   'pickup_latitude': 40.764142,
#   'pickup_longitude': -73.95442,
#   'distance_from_selected': 0.2102847878568507},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.7642,
#   'pickup_longitude': -73.954807,
#   'distance_from_selected': 0.2106366011618175},
#  {'trip_distance': 6.52,
#   'pickup_latitude': 40.766602,
#   'pickup_longitude': -73.95388,
#   'distance_from_selected': 0.21124661285805324},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.768924,
#   'pickup_longitude': -73.952227,
#   'distance_from_selected': 0.21125097937050735},
#  {'trip_distance': 2.29,
#   'pickup_latitude': 40.772207,
#   'pickup_longitude': -73.94992,
#   'distance_from_selected': 0.21134681920720627},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.768197,
#   'pickup_longitude': -73.952871,
#   'distance_from_selected': 0.21134821193944825},
#  {'trip_distance': 2.11,
#   'pickup_latitude': 40.76944,
#   'pickup_longitude': -73.952025,
#   'distance_from_selected': 0.21139079479722855},
#  {'trip_distance': 5.88,
#   'pickup_latitude': 40.775122,
#   'pickup_longitude': -73.947765,
#   'distance_from_selected': 0.21141167339814346},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.775985,
#   'pickup_longitude': -73.947142,
#   'distance_from_selected': 0.21145456743471058},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.776247,
#   'pickup_longitude': -73.94696,
#   'distance_from_selected': 0.21147424464695924},
#  {'trip_distance': 7.1,
#   'pickup_latitude': 40.777867,
#   'pickup_longitude': -73.945725,
#   'distance_from_selected': 0.21152122293992134},
#  {'trip_distance': 0.64,
#   'pickup_latitude': 40.760442,
#   'pickup_longitude': -73.958405,
#   'distance_from_selected': 0.21153841100140727},
#  {'trip_distance': 1.33,
#   'pickup_latitude': 40.77831,
#   'pickup_longitude': -73.9454,
#   'distance_from_selected': 0.21154735852759446},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.762465,
#   'pickup_longitude': -73.957122,
#   'distance_from_selected': 0.21158100200396132},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.778415,
#   'pickup_longitude': -73.945392,
#   'distance_from_selected': 0.2116073372759111},
#  {'trip_distance': 2.48,
#   'pickup_latitude': 40.767342,
#   'pickup_longitude': -73.954357,
#   'distance_from_selected': 0.21206290753689475},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.72635,
#   'pickup_longitude': -73.977049,
#   'distance_from_selected': 0.21212229444591232},
#  {'trip_distance': 2.9,
#   'pickup_latitude': 40.761926,
#   'pickup_longitude': -73.958256,
#   'distance_from_selected': 0.21222762151049948},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.726413,
#   'pickup_longitude': -73.977196,
#   'distance_from_selected': 0.21228221556457327},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.755617,
#   'pickup_longitude': -73.962448,
#   'distance_from_selected': 0.2123847874330917},
#  {'trip_distance': 5.5,
#   'pickup_latitude': 40.688702,
#   'pickup_longitude': -73.98921,
#   'distance_from_selected': 0.2126022166958785},
#  {'trip_distance': 0.45,
#   'pickup_latitude': 40.769387,
#   'pickup_longitude': -73.953623,
#   'distance_from_selected': 0.21265358999555892},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.732893,
#   'pickup_longitude': -73.974918,
#   'distance_from_selected': 0.2127744703506549},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.724007,
#   'pickup_longitude': -73.978812,
#   'distance_from_selected': 0.21287074137373435},
#  {'trip_distance': 4.8,
#   'pickup_latitude': 40.724197,
#   'pickup_longitude': -73.978797,
#   'distance_from_selected': 0.21292741828614004},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.687077,
#   'pickup_longitude': -73.990203,
#   'distance_from_selected': 0.21324744401281587},
#  {'trip_distance': 1.24,
#   'pickup_latitude': 40.767777,
#   'pickup_longitude': -73.955538,
#   'distance_from_selected': 0.2132787422904665},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.768967,
#   'pickup_longitude': -73.954822,
#   'distance_from_selected': 0.21338289554929088},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.722856,
#   'pickup_longitude': -73.979826,
#   'distance_from_selected': 0.21338994102816197},
#  {'trip_distance': 0.83,
#   'pickup_latitude': 40.772327,
#   'pickup_longitude': -73.952635,
#   'distance_from_selected': 0.21359264218132767},
#  {'trip_distance': 1.78,
#   'pickup_latitude': 40.775272,
#   'pickup_longitude': -73.95043,
#   'distance_from_selected': 0.21360973274642817},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.777513,
#   'pickup_longitude': -73.948801,
#   'distance_from_selected': 0.21370354075214082},
#  {'trip_distance': 1.76,
#   'pickup_latitude': 40.77225,
#   'pickup_longitude': -73.95285,
#   'distance_from_selected': 0.21371943664533735},
#  {'trip_distance': 4.9,
#   'pickup_latitude': 40.771552,
#   'pickup_longitude': -73.953405,
#   'distance_from_selected': 0.21375154939555957},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.766653,
#   'pickup_longitude': -73.957138,
#   'distance_from_selected': 0.21394780137454292},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.78079,
#   'pickup_longitude': -73.946522,
#   'distance_from_selected': 0.213984902233785},
#  {'trip_distance': 2.61,
#   'pickup_latitude': 40.763262,
#   'pickup_longitude': -73.95948,
#   'distance_from_selected': 0.21398564177065785},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.763028,
#   'pickup_longitude': -73.959639,
#   'distance_from_selected': 0.21398900103743487},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.770567,
#   'pickup_longitude': -73.954641,
#   'distance_from_selected': 0.21416981582379774},
#  {'trip_distance': 0.72,
#   'pickup_latitude': 40.758372,
#   'pickup_longitude': -73.963047,
#   'distance_from_selected': 0.21434084196205505},
#  {'trip_distance': 0.58,
#   'pickup_latitude': 40.755637,
#   'pickup_longitude': -73.96482,
#   'distance_from_selected': 0.2144234770471797},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.757465,
#   'pickup_longitude': -73.963752,
#   'distance_from_selected': 0.21446238837847956},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.761082,
#   'pickup_longitude': -73.961535,
#   'distance_from_selected': 0.21451363753617353},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.743896,
#   'pickup_longitude': -73.971551,
#   'distance_from_selected': 0.21455753922200713},
#  {'trip_distance': 0.12,
#   'pickup_latitude': 40.742682,
#   'pickup_longitude': -73.972513,
#   'distance_from_selected': 0.21485698646542573},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.753392,
#   'pickup_longitude': -73.966885,
#   'distance_from_selected': 0.21505460662120826},
#  {'trip_distance': 4.85,
#   'pickup_latitude': 40.750722,
#   'pickup_longitude': -73.968447,
#   'distance_from_selected': 0.2150800363422906},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.75681,
#   'pickup_longitude': -73.96498,
#   'distance_from_selected': 0.21516779800890395},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.760643,
#   'pickup_longitude': -73.962616,
#   'distance_from_selected': 0.21518718726959685},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.726783,
#   'pickup_longitude': -73.980283,
#   'distance_from_selected': 0.21527667439367631},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.757437,
#   'pickup_longitude': -73.964735,
#   'distance_from_selected': 0.2152853456090395},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.777566,
#   'pickup_longitude': -73.950919,
#   'distance_from_selected': 0.21540173893680814},
#  {'trip_distance': 3.0,
#   'pickup_latitude': 40.689592,
#   'pickup_longitude': -73.992087,
#   'distance_from_selected': 0.2156009192304159},
#  {'trip_distance': 2.24,
#   'pickup_latitude': 40.689827,
#   'pickup_longitude': -73.99235,
#   'distance_from_selected': 0.21590691644549576},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.744277,
#   'pickup_longitude': -73.973007,
#   'distance_from_selected': 0.21602550038826185},
#  {'trip_distance': 0.53,
#   'pickup_latitude': 40.77338,
#   'pickup_longitude': -73.954888,
#   'distance_from_selected': 0.21602982373737395},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.758647,
#   'pickup_longitude': -73.964878,
#   'distance_from_selected': 0.21604141184736217},
#  {'trip_distance': 0.43,
#   'pickup_latitude': 40.765242,
#   'pickup_longitude': -73.960702,
#   'distance_from_selected': 0.21610058817134337},
#  {'trip_distance': 4.16,
#   'pickup_latitude': 40.74909,
#   'pickup_longitude': -73.970552,
#   'distance_from_selected': 0.21612479636543552},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.768895,
#   'pickup_longitude': -73.958237,
#   'distance_from_selected': 0.21613017973897172},
#  {'trip_distance': 2.9,
#   'pickup_latitude': 40.77081,
#   'pickup_longitude': -73.956903,
#   'distance_from_selected': 0.21614761023198809},
#  {'trip_distance': 4.33,
#   'pickup_latitude': 40.771152,
#   'pickup_longitude': -73.95672,
#   'distance_from_selected': 0.2161982311306058},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.722982,
#   'pickup_longitude': -73.982842,
#   'distance_from_selected': 0.2162461905514261},
#  {'trip_distance': 1.42,
#   'pickup_latitude': 40.783447,
#   'pickup_longitude': -73.947283,
#   'distance_from_selected': 0.21626491749241572},
#  {'trip_distance': 9.22,
#   'pickup_latitude': 40.771907,
#   'pickup_longitude': -73.95626,
#   'distance_from_selected': 0.2162670501694629},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902,
#   'distance_from_selected': 0.2162779533470808},
#  {'trip_distance': 3.25,
#   'pickup_latitude': 40.776315,
#   'pickup_longitude': -73.952995,
#   'distance_from_selected': 0.21627981794425657},
#  {'trip_distance': 2.58,
#   'pickup_latitude': 40.770737,
#   'pickup_longitude': -73.957142,
#   'distance_from_selected': 0.21629954247062572},
#  {'trip_distance': 3.04,
#   'pickup_latitude': 40.7649,
#   'pickup_longitude': -73.9612,
#   'distance_from_selected': 0.21632478036508532},
#  {'trip_distance': 2.65,
#   'pickup_latitude': 40.765862,
#   'pickup_longitude': -73.9606,
#   'distance_from_selected': 0.21636160214788724},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.743102,
#   'pickup_longitude': -73.973988,
#   'distance_from_selected': 0.21636186999562454},
#  {'trip_distance': 1.08,
#   'pickup_latitude': 40.74933,
#   'pickup_longitude': -73.97076,
#   'distance_from_selected': 0.21642270606385278},
#  {'trip_distance': 0.63,
#   'pickup_latitude': 40.721897,
#   'pickup_longitude': -73.983493,
#   'distance_from_selected': 0.21646564692347695},
#  {'trip_distance': 3.01,
#   'pickup_latitude': 40.783138,
#   'pickup_longitude': -73.947885,
#   'distance_from_selected': 0.2165304369574892},
#  {'trip_distance': 4.8,
#   'pickup_latitude': 40.782873,
#   'pickup_longitude': -73.948122,
#   'distance_from_selected': 0.21654415363385135},
#  {'trip_distance': 2.86,
#   'pickup_latitude': 40.661145,
#   'pickup_longitude': -73.997122,
#   'distance_from_selected': 0.21657536519420512},
#  {'trip_distance': 1.85,
#   'pickup_latitude': 40.756397,
#   'pickup_longitude': -73.966882,
#   'distance_from_selected': 0.2165823064633871},
#  {'trip_distance': 8.44,
#   'pickup_latitude': 40.696647,
#   'pickup_longitude': -73.99152,
#   'distance_from_selected': 0.21661944176134978},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.78277,
#   'pickup_longitude': -73.948383,
#   'distance_from_selected': 0.21667995913098015},
#  {'trip_distance': 1.71,
#   'pickup_latitude': 40.742032,
#   'pickup_longitude': -73.97492,
#   'distance_from_selected': 0.21671170403095588},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.76003,
#   'pickup_longitude': -73.964842,
#   'distance_from_selected': 0.21674167219065868},
#  {'trip_distance': 1.05,
#   'pickup_latitude': 40.75331,
#   'pickup_longitude': -73.968992,
#   'distance_from_selected': 0.21683597340847544},
#  {'trip_distance': 2.11,
#   'pickup_latitude': 40.763152,
#   'pickup_longitude': -73.962962,
#   'distance_from_selected': 0.2168360246545818},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.75885,
#   'pickup_longitude': -73.965817,
#   'distance_from_selected': 0.2169469992624979},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.756412,
#   'pickup_longitude': -73.967363,
#   'distance_from_selected': 0.2170026346683443},
#  {'trip_distance': 2.02,
#   'pickup_latitude': 40.754852,
#   'pickup_longitude': -73.968343,
#   'distance_from_selected': 0.21705040495931543},
#  {'trip_distance': 3.06,
#   'pickup_latitude': 40.756667,
#   'pickup_longitude': -73.967298,
#   'distance_from_selected': 0.2170779358502405},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.756392,
#   'pickup_longitude': -73.967522,
#   'distance_from_selected': 0.21712882809061018},
#  {'trip_distance': 5.3,
#   'pickup_latitude': 40.754753,
#   'pickup_longitude': -73.968547,
#   'distance_from_selected': 0.2171763149563087},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.753168,
#   'pickup_longitude': -73.969728,
#   'distance_from_selected': 0.21740317791606237},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.75377,
#   'pickup_longitude': -73.969407,
#   'distance_from_selected': 0.2174253583393698},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.751217,
#   'pickup_longitude': -73.970895,
#   'distance_from_selected': 0.21745652566432705},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.737486,
#   'pickup_longitude': -73.978153,
#   'distance_from_selected': 0.2176366054343872},
#  {'trip_distance': 2.66,
#   'pickup_latitude': 40.752447,
#   'pickup_longitude': -73.970462,
#   'distance_from_selected': 0.2176833484513679},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 40.748567,
#   'pickup_longitude': -73.972642,
#   'distance_from_selected': 0.2177093957389047},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.793261,
#   'pickup_longitude': -73.940565,
#   'distance_from_selected': 0.21770951211649775},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.751837,
#   'pickup_longitude': -73.970865,
#   'distance_from_selected': 0.2177339262356764},
#  {'trip_distance': 1.71,
#   'pickup_latitude': 40.751285,
#   'pickup_longitude': -73.9712,
#   'distance_from_selected': 0.21775589435191045},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.659956,
#   'pickup_longitude': -73.99842,
#   'distance_from_selected': 0.2177848343112984},
#  {'trip_distance': 0.48,
#   'pickup_latitude': 40.74964,
#   'pickup_longitude': -73.972212,
#   'distance_from_selected': 0.21784469317383143},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.718208,
#   'pickup_longitude': -73.986443,
#   'distance_from_selected': 0.21795892129710717},
#  {'trip_distance': 0.95,
#   'pickup_latitude': 40.726162,
#   'pickup_longitude': -73.983432,
#   'distance_from_selected': 0.21796077882958448},
#  {'trip_distance': 0.06,
#   'pickup_latitude': 40.751087,
#   'pickup_longitude': -73.9716,
#   'distance_from_selected': 0.21800866016972595},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.750693,
#   'pickup_longitude': -73.971834,
#   'distance_from_selected': 0.2180218155712895},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.735118,
#   'pickup_longitude': -73.97979,
#   'distance_from_selected': 0.21813047926412987},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.748453,
#   'pickup_longitude': -73.973209,
#   'distance_from_selected': 0.21815419283158352},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.734659,
#   'pickup_longitude': -73.98004,
#   'distance_from_selected': 0.21816911252742086},
#  {'trip_distance': 21.24,
#   'pickup_latitude': 40.76767,
#   'pickup_longitude': -73.96166,
#   'distance_from_selected': 0.21825270330513658},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.769545,
#   'pickup_longitude': -73.960554,
#   'distance_from_selected': 0.21840270886827864},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.768339,
#   'pickup_longitude': -73.961478,
#   'distance_from_selected': 0.21847920584119773},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.771909,
#   'pickup_longitude': -73.959023,
#   'distance_from_selected': 0.21851141089197632},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.723516,
#   'pickup_longitude': -73.985065,
#   'distance_from_selected': 0.21851237928548395},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.747572,
#   'pickup_longitude': -73.974092,
#   'distance_from_selected': 0.21851700640453697},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.747263,
#   'pickup_longitude': -73.974266,
#   'distance_from_selected': 0.21852587028770906},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.770319,
#   'pickup_longitude': -73.960222,
#   'distance_from_selected': 0.21857296133099804},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.769822,
#   'pickup_longitude': -73.960596,
#   'distance_from_selected': 0.2185952770304038},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.7678,
#   'pickup_longitude': -73.961987,
#   'distance_from_selected': 0.21859624120510202},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.782582,
#   'pickup_longitude': -73.951088,
#   'distance_from_selected': 0.21865608225704605},
#  {'trip_distance': 1.21,
#   'pickup_latitude': 40.780672,
#   'pickup_longitude': -73.952653,
#   'distance_from_selected': 0.21868443962248707},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.771542,
#   'pickup_longitude': -73.959533,
#   'distance_from_selected': 0.2187142048267509},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.758905,
#   'pickup_longitude': -73.967897,
#   'distance_from_selected': 0.21874887253194822},
#  {'trip_distance': 1.34,
#   'pickup_latitude': 40.78232,
#   'pickup_longitude': -73.951423,
#   'distance_from_selected': 0.21875196782886916},
#  {'trip_distance': 2.67,
#   'pickup_latitude': 40.7331,
#   'pickup_longitude': -73.981375,
#   'distance_from_selected': 0.21875425190153755},
#  {'trip_distance': 0.97,
#   'pickup_latitude': 40.777707,
#   'pickup_longitude': -73.955068,
#   'distance_from_selected': 0.218772193875273},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.763332,
#   'pickup_longitude': -73.965163,
#   'distance_from_selected': 0.2187821133753907},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.718429,
#   'pickup_longitude': -73.987265,
#   'distance_from_selected': 0.21880740377327},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.744422,
#   'pickup_longitude': -73.976127,
#   'distance_from_selected': 0.21886697593059443},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.763434,
#   'pickup_longitude': -73.965213,
#   'distance_from_selected': 0.21887934828348357},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.757889,
#   'pickup_longitude': -73.968702,
#   'distance_from_selected': 0.2189107966843994},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.760195,
#   'pickup_longitude': -73.967307,
#   'distance_from_selected': 0.21892149431703573},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 40.756806,
#   'pickup_longitude': -73.969385,
#   'distance_from_selected': 0.2189411635143142},
#  {'trip_distance': 0.72,
#   'pickup_latitude': 40.75708,
#   'pickup_longitude': -73.96923,
#   'distance_from_selected': 0.21894806347625048},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.743411,
#   'pickup_longitude': -73.97686,
#   'distance_from_selected': 0.21906413978787692},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.758157,
#   'pickup_longitude': -73.968752,
#   'distance_from_selected': 0.21909194483823155},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.75966,
#   'pickup_longitude': -73.96785,
#   'distance_from_selected': 0.21910294133123806},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.756636,
#   'pickup_longitude': -73.9697,
#   'distance_from_selected': 0.2191253792147375},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.72235,
#   'pickup_longitude': -73.986202,
#   'distance_from_selected': 0.21915951337782158},
#  {'trip_distance': 6.58,
#   'pickup_latitude': 40.801657,
#   'pickup_longitude': -73.934415,
#   'distance_from_selected': 0.21916822104037126},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.767331,
#   'pickup_longitude': -73.962998,
#   'distance_from_selected': 0.21917120108490643},
#  {'trip_distance': 4.0,
#   'pickup_latitude': 40.721988,
#   'pickup_longitude': -73.986383,
#   'distance_from_selected': 0.21920145139346892},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.774627,
#   'pickup_longitude': -73.957909,
#   'distance_from_selected': 0.2192019522039028},
#  {'trip_distance': 2.45,
#   'pickup_latitude': 40.732882,
#   'pickup_longitude': -73.981975,
#   'distance_from_selected': 0.21921606758858478},
#  {'trip_distance': 1.93,
#   'pickup_latitude': 40.754822,
#   'pickup_longitude': -73.971017,
#   'distance_from_selected': 0.21934572234944982},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.783417,
#   'pickup_longitude': -73.951313,
#   'distance_from_selected': 0.2193569713913848},
#  {'trip_distance': 5.37,
#   'pickup_latitude': 40.759172,
#   'pickup_longitude': -73.968517,
#   'distance_from_selected': 0.21941723226083054},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.76102,
#   'pickup_longitude': -73.967407,
#   'distance_from_selected': 0.21944163449309162},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.759795,
#   'pickup_longitude': -73.968202,
#   'distance_from_selected': 0.21947354904179786},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.759037,
#   'pickup_longitude': -73.968693,
#   'distance_from_selected': 0.21949736913685725},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.741568,
#   'pickup_longitude': -73.978341,
#   'distance_from_selected': 0.21957140197439562},
#  {'trip_distance': 2.01,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.968163,
#   'distance_from_selected': 0.21957749579135735},
#  {'trip_distance': 2.07,
#   'pickup_latitude': 40.719972,
#   'pickup_longitude': -73.987553,
#   'distance_from_selected': 0.21960077124865343},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.77919,
#   'pickup_longitude': -73.954987,
#   'distance_from_selected': 0.21961088900371506},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.750617,
#   'pickup_longitude': -73.97391,
#   'distance_from_selected': 0.2198032773390841},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.754248,
#   'pickup_longitude': -73.972058,
#   'distance_from_selected': 0.21996175810354437},
#  {'trip_distance': 3.3,
#   'pickup_latitude': 40.719963,
#   'pickup_longitude': -73.987997,
#   'distance_from_selected': 0.22001507252458508},
#  {'trip_distance': 0.62,
#   'pickup_latitude': 40.7595,
#   'pickup_longitude': -73.96904,
#   'distance_from_selected': 0.22003452501824441},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.777608,
#   'pickup_longitude': -73.956815,
#   'distance_from_selected': 0.22010389853204207},
#  {'trip_distance': 3.7,
#   'pickup_latitude': 40.781112,
#   'pickup_longitude': -73.954135,
#   'distance_from_selected': 0.2201204422787649},
#  {'trip_distance': 2.62,
#   'pickup_latitude': 40.782512,
#   'pickup_longitude': -73.95305,
#   'distance_from_selected': 0.22014066067858049},
#  {'trip_distance': 3.68,
#   'pickup_latitude': 40.774172,
#   'pickup_longitude': -73.959412,
#   'distance_from_selected': 0.22014842667618897},
#  {'trip_distance': 3.98,
#   'pickup_latitude': 40.727475,
#   'pickup_longitude': -73.98533,
#   'distance_from_selected': 0.22021182444410883},
#  {'trip_distance': 7.46,
#   'pickup_latitude': 40.72245,
#   'pickup_longitude': -73.98729,
#   'distance_from_selected': 0.22021296782887773},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.767867,
#   'pickup_longitude': -73.963893,
#   'distance_from_selected': 0.220212990484216},
#  {'trip_distance': 0.37,
#   'pickup_latitude': 40.770792,
#   'pickup_longitude': -73.961915,
#   'distance_from_selected': 0.22023198775155928},
#  {'trip_distance': 1.65,
#   'pickup_latitude': 40.769862,
#   'pickup_longitude': -73.962567,
#   'distance_from_selected': 0.22023883461597915},
#  {'trip_distance': 1.12,
#   'pickup_latitude': 40.720457,
#   'pickup_longitude': -73.988065,
#   'distance_from_selected': 0.22024778163242495},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.773736,
#   'pickup_longitude': -73.959905,
#   'distance_from_selected': 0.22029272012711476},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.776252,
#   'pickup_longitude': -73.958072,
#   'distance_from_selected': 0.22029776832278974},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.768712,
#   'pickup_longitude': -73.963437,
#   'distance_from_selected': 0.22030815612001528},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.772357,
#   'pickup_longitude': -73.960927,
#   'distance_from_selected': 0.22032276872352616},
#  {'trip_distance': 2.88,
#   'pickup_latitude': 40.722532,
#   'pickup_longitude': -73.987428,
#   'distance_from_selected': 0.2203709941167375},
#  {'trip_distance': 6.6,
#   'pickup_latitude': 40.75318,
#   'pickup_longitude': -73.973152,
#   'distance_from_selected': 0.22038567127651687},
#  {'trip_distance': 2.5,
#   'pickup_latitude': 40.783897,
#   'pickup_longitude': -73.952306,
#   'distance_from_selected': 0.22043033136344833},
#  {'trip_distance': 2.32,
#   'pickup_latitude': 40.782595,
#   'pickup_longitude': -73.953385,
#   'distance_from_selected': 0.2204541477269148},
#  {'trip_distance': 8.9,
#   'pickup_latitude': 40.767302,
#   'pickup_longitude': -73.9646,
#   'distance_from_selected': 0.22048611712305838},
#  {'trip_distance': 0.76,
#   'pickup_latitude': 40.753485,
#   'pickup_longitude': -73.97311,
#   'distance_from_selected': 0.22049899461222697},
#  {'trip_distance': 9.28,
#   'pickup_latitude': 40.736197,
#   'pickup_longitude': -73.981978,
#   'distance_from_selected': 0.22056881564038017},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.722958,
#   'pickup_longitude': -73.987498,
#   'distance_from_selected': 0.22058673153207117},
#  {'trip_distance': 0.4,
#   'pickup_latitude': 40.785612,
#   'pickup_longitude': -73.951147,
#   'distance_from_selected': 0.22062077620433504},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.726597,
#   'pickup_longitude': -73.986165,
#   'distance_from_selected': 0.2206600386884788},
#  {'trip_distance': 1.79,
#   'pickup_latitude': 40.724477,
#   'pickup_longitude': -73.98706,
#   'distance_from_selected': 0.2207195307828495},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.762243,
#   'pickup_longitude': -73.96815,
#   'distance_from_selected': 0.22071988131792442},
#  {'trip_distance': 0.84,
#   'pickup_latitude': 40.762912,
#   'pickup_longitude': -73.967782,
#   'distance_from_selected': 0.22076481039332593},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.750938,
#   'pickup_longitude': -73.974878,
#   'distance_from_selected': 0.22080651414304417},
#  {'trip_distance': 5.4,
#   'pickup_latitude': 40.7455,
#   'pickup_longitude': -73.977834,
#   'distance_from_selected': 0.2208774681944762},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.762111,
#   'pickup_longitude': -73.968438,
#   'distance_from_selected': 0.22089391930291544},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.758261,
#   'pickup_longitude': -73.970859,
#   'distance_from_selected': 0.22095208557966212},
#  {'trip_distance': 7.27,
#   'pickup_latitude': 40.789342,
#   'pickup_longitude': -73.948455,
#   'distance_from_selected': 0.22097163376551077},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.760955,
#   'pickup_longitude': -73.969252,
#   'distance_from_selected': 0.22097566297898258},
#  {'trip_distance': 3.61,
#   'pickup_latitude': 40.74733,
#   'pickup_longitude': -73.97703,
#   'distance_from_selected': 0.22100328051863977},
#  {'trip_distance': 2.39,
#   'pickup_latitude': 40.747967,
#   'pickup_longitude': -73.976727,
#   'distance_from_selected': 0.22103082467837062},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.749559,
#   'pickup_longitude': -73.975903,
#   'distance_from_selected': 0.22105068823688787},
#  {'trip_distance': 1.41,
#   'pickup_latitude': 40.75726,
#   'pickup_longitude': -73.97158,
#   'distance_from_selected': 0.22106138921123908},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.755123,
#   'pickup_longitude': -73.97283,
#   'distance_from_selected': 0.22106673220772377},
#  {'trip_distance': 2.54,
#   'pickup_latitude': 40.755972,
#   'pickup_longitude': -73.972347,
#   'distance_from_selected': 0.22107305836080737},
#  {'trip_distance': 1.18,
#   'pickup_latitude': 40.745012,
#   'pickup_longitude': -73.978387,
#   'distance_from_selected': 0.22114889701963478},
#  {'trip_distance': 3.3,
#   'pickup_latitude': 40.762551,
#   'pickup_longitude': -73.968469,
#   'distance_from_selected': 0.22115378468839575},
#  {'trip_distance': 0.74,
#   'pickup_latitude': 40.7464,
#   'pickup_longitude': -73.97771,
#   'distance_from_selected': 0.22117825774700892},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.7456,
#   'pickup_longitude': -73.97814,
#   'distance_from_selected': 0.22119546152667885},
#  {'trip_distance': 12.7,
#   'pickup_latitude': 40.732141,
#   'pickup_longitude': -73.98447,
#   'distance_from_selected': 0.2212110286604215},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.759825,
#   'pickup_longitude': -73.970231,
#   'distance_from_selected': 0.2212209343303668},
#  {'trip_distance': 2.9,
#   'pickup_latitude': 40.728097,
#   'pickup_longitude': -73.986215,
#   'distance_from_selected': 0.2212655139736006},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.744896,
#   'pickup_longitude': -73.978619,
#   'distance_from_selected': 0.2213034450635568},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.75185,
#   'pickup_longitude': -73.97495,
#   'distance_from_selected': 0.2213086071530057},
#  {'trip_distance': 0.43,
#   'pickup_latitude': 40.745647,
#   'pickup_longitude': -73.978275,
#   'distance_from_selected': 0.22133706710354584},
#  {'trip_distance': 1.92,
#   'pickup_latitude': 40.71879,
#   'pickup_longitude': -73.98984,
#   'distance_from_selected': 0.22135481946413899},
#  {'trip_distance': 7.6,
#   'pickup_latitude': 40.752342,
#   'pickup_longitude': -73.974746,
#   'distance_from_selected': 0.22136816193843123},
#  {'trip_distance': 3.02,
#   'pickup_latitude': 40.744682,
#   'pickup_longitude': -73.978817,
#   'distance_from_selected': 0.22138368899492883},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.743594,
#   'pickup_longitude': -73.979374,
#   'distance_from_selected': 0.22139445113192077},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.745217,
#   'pickup_longitude': -73.978587,
#   'distance_from_selected': 0.22142000925391195},
#  {'trip_distance': 1.23,
#   'pickup_latitude': 40.762202,
#   'pickup_longitude': -73.969015,
#   'distance_from_selected': 0.2214315044635729},
#  {'trip_distance': 2.2,
#   'pickup_latitude': 40.746333,
#   'pickup_longitude': -73.978038,
#   'distance_from_selected': 0.22143912976933525},
#  {'trip_distance': 2.04,
#   'pickup_latitude': 40.722785,
#   'pickup_longitude': -73.988558,
#   'distance_from_selected': 0.22151781077150584},
#  {'trip_distance': 0.25,
#   'pickup_latitude': 40.761363,
#   'pickup_longitude': -73.969672,
#   'distance_from_selected': 0.22154733041272012},
#  {'trip_distance': 16.0,
#   'pickup_latitude': 40.754789,
#   'pickup_longitude': -73.973606,
#   'distance_from_selected': 0.22157421406157182},
#  {'trip_distance': 1.42,
#   'pickup_latitude': 40.780082,
#   'pickup_longitude': -73.956843,
#   'distance_from_selected': 0.2216255371409248},
#  {'trip_distance': 11.3,
#   'pickup_latitude': 40.779416,
#   'pickup_longitude': -73.957448,
#   'distance_from_selected': 0.2217010019824005},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.751251,
#   'pickup_longitude': -73.975745,
#   'distance_from_selected': 0.22171741958178065},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.722397,
#   'pickup_longitude': -73.988933,
#   'distance_from_selected': 0.22173321523398956},
#  {'trip_distance': 4.1,
#   'pickup_latitude': 40.774029,
#   'pickup_longitude': -73.961478,
#   'distance_from_selected': 0.22174140593267813},
#  {'trip_distance': 2.63,
#   'pickup_latitude': 40.754807,
#   'pickup_longitude': -73.97379,
#   'distance_from_selected': 0.2217429662672502},
#  {'trip_distance': 4.11,
#   'pickup_latitude': 40.721882,
#   'pickup_longitude': -73.989213,
#   'distance_from_selected': 0.22181657204321825},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.723036,
#   'pickup_longitude': -73.988783,
#   'distance_from_selected': 0.22181668288251138},
#  {'trip_distance': 3.9,
#   'pickup_latitude': 40.751124,
#   'pickup_longitude': -73.975967,
#   'distance_from_selected': 0.22185150313892307},
#  {'trip_distance': 1.14,
#   'pickup_latitude': 40.768512,
#   'pickup_longitude': -73.965495,
#   'distance_from_selected': 0.22190259914882268},
#  {'trip_distance': 1.07,
#   'pickup_latitude': 40.751055,
#   'pickup_longitude': -73.97607,
#   'distance_from_selected': 0.22190896923063805},
#  {'trip_distance': 6.7,
#   'pickup_latitude': 40.756005,
#   'pickup_longitude': -73.973294,
#   'distance_from_selected': 0.22190909616552457},
#  {'trip_distance': 6.2,
#   'pickup_latitude': 40.752788,
#   'pickup_longitude': -73.975128,
#   'distance_from_selected': 0.2219186186150253},
#  {'trip_distance': 2.52,
#   'pickup_latitude': 40.774015,
#   'pickup_longitude': -73.961737,
#   'distance_from_selected': 0.2219439460629657},
#  {'trip_distance': 4.83,
#   'pickup_latitude': 40.774852,
#   'pickup_longitude': -73.961215,
#   'distance_from_selected': 0.2220079801921552},
#  {'trip_distance': 2.41,
#   'pickup_latitude': 40.778885,
#   'pickup_longitude': -73.958245,
#   'distance_from_selected': 0.22201466179062065},
#  {'trip_distance': 0.78,
#   'pickup_latitude': 40.770965,
#   'pickup_longitude': -73.964002,
#   'distance_from_selected': 0.2220462891583601},
#  {'trip_distance': 1.27,
#   'pickup_latitude': 40.772847,
#   'pickup_longitude': -73.962703,
#   'distance_from_selected': 0.22205608358701326},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.771168,
#   'pickup_longitude': -73.963929,
#   'distance_from_selected': 0.22210144196965376},
#  {'trip_distance': 1.14,
#   'pickup_latitude': 40.777652,
#   'pickup_longitude': -73.959298,
#   'distance_from_selected': 0.222116897484193},
#  {'trip_distance': 0.25,
#   'pickup_latitude': 40.77958,
#   'pickup_longitude': -73.957862,
#   'distance_from_selected': 0.22212968969501573},
#  {'trip_distance': 3.0,
#   'pickup_latitude': 40.717487,
#   'pickup_longitude': -73.99113,
#   'distance_from_selected': 0.22214278158202766},
#  {'trip_distance': 1.51,
#   'pickup_latitude': 40.741275,
#   'pickup_longitude': -73.981362,
#   'distance_from_selected': 0.22216130664227599},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.755034,
#   'pickup_longitude': -73.974168,
#   'distance_from_selected': 0.2221837758703457},
#  {'trip_distance': 0.88,
#   'pickup_latitude': 40.717055,
#   'pickup_longitude': -73.991325,
#   'distance_from_selected': 0.22218662167196992},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.730145,
#   'pickup_longitude': -73.986395,
#   'distance_from_selected': 0.22220909983617257},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.783298,
#   'pickup_longitude': -73.955095,
#   'distance_from_selected': 0.2222295342410674},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.762908,
#   'pickup_longitude': -73.969549,
#   'distance_from_selected': 0.22225849348225643},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.783545,
#   'pickup_longitude': -73.954963,
#   'distance_from_selected': 0.22228010930805858},
#  {'trip_distance': 3.6,
#   'pickup_latitude': 40.782011,
#   'pickup_longitude': -73.956252,
#   'distance_from_selected': 0.222340875335604},
#  {'trip_distance': 2.08,
#   'pickup_latitude': 40.740045,
#   'pickup_longitude': -73.982178,
#   'distance_from_selected': 0.22236841009685618},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.76495,
#   'pickup_longitude': -73.968502,
#   'distance_from_selected': 0.22246611765390548},
#  {'trip_distance': 1.01,
#   'pickup_latitude': 40.74969,
#   'pickup_longitude': -73.97751,
#   'distance_from_selected': 0.22252941288737466},
#  {'trip_distance': 2.56,
#   'pickup_latitude': 40.763502,
#   'pickup_longitude': -73.96952,
#   'distance_from_selected': 0.22254965972565074},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.76305,
#   'pickup_longitude': -73.969831,
#   'distance_from_selected': 0.22257287202397538},
#  {'trip_distance': 5.79,
#   'pickup_latitude': 40.74892,
#   'pickup_longitude': -73.97797,
#   'distance_from_selected': 0.22257483528018301},
#  {'trip_distance': 1.63,
#   'pickup_latitude': 40.729602,
#   'pickup_longitude': -73.987032,
#   'distance_from_selected': 0.22259062978481606},
#  {'trip_distance': 10.9,
#   'pickup_latitude': 40.751953,
#   'pickup_longitude': -73.976404,
#   'distance_from_selected': 0.22263245020661804},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.787654,
#   'pickup_longitude': -73.952104,
#   'distance_from_selected': 0.22266182208004145},
#  {'trip_distance': 2.7,
#   'pickup_latitude': 40.75652,
#   'pickup_longitude': -73.973926,
#   'distance_from_selected': 0.2227140028736495},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.732783,
#   'pickup_longitude': -73.985831,
#   'distance_from_selected': 0.2227148908582514},
#  {'trip_distance': 16.4,
#   'pickup_latitude': 40.728808,
#   'pickup_longitude': -73.987538,
#   'distance_from_selected': 0.2227587566584124},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.76084,
#   'pickup_longitude': -73.971439,
#   'distance_from_selected': 0.22278044353354515},
#  {'trip_distance': 3.79,
#   'pickup_latitude': 40.73918,
#   'pickup_longitude': -73.98305,
#   'distance_from_selected': 0.22278995960321732},
#  {'trip_distance': 3.8,
#   'pickup_latitude': 40.738254,
#   'pickup_longitude': -73.983499,
#   'distance_from_selected': 0.22280774559471406},
#  {'trip_distance': 1.49,
#   'pickup_latitude': 40.771385,
#   'pickup_longitude': -73.96467,
#   'distance_from_selected': 0.22283466163279245},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.746032,
#   'pickup_longitude': -73.97976,
#   'distance_from_selected': 0.2228349565575401},
#  {'trip_distance': 1.03,
#   'pickup_latitude': 40.75619,
#   'pickup_longitude': -73.974282,
#   'distance_from_selected': 0.22285737462332592},
#  {'trip_distance': 3.59,
#   'pickup_latitude': 40.7582,
#   'pickup_longitude': -73.973285,
#   'distance_from_selected': 0.22300753871787246},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.746683,
#   'pickup_longitude': -73.979712,
#   'distance_from_selected': 0.22308817560104638},
# ...
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.7169,
#   'pickup_longitude': -74.0127,
#   'distance_from_selected': 0.24245917305806294},
#  {'trip_distance': 1.93,
#   'pickup_latitude': 40.740482,
#   'pickup_longitude': -74.004042,
#   'distance_from_selected': 0.2424862176042192},
#  {'trip_distance': 0.76,
#   'pickup_latitude': 40.794572,
#   'pickup_longitude': -73.97205,
#   'distance_from_selected': 0.2425233694389066},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.735785,
#   'pickup_longitude': -74.006038,
#   'distance_from_selected': 0.24252493597360908},
#  {'trip_distance': 0.53,
#   'pickup_latitude': 40.787172,
#   'pickup_longitude': -73.97763,
#   'distance_from_selected': 0.2425285787778478},
#  {'trip_distance': 4.2,
#   'pickup_latitude': 40.799458,
#   'pickup_longitude': -73.968139,
#   'distance_from_selected': 0.24253917033130812},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.764774,
#   'pickup_longitude': -73.992049,
#   'distance_from_selected': 0.2425419445312495},
#  {'trip_distance': 0.2,
#   'pickup_latitude': 40.7951,
#   'pickup_longitude': -73.97166,
#   'distance_from_selected': 0.24254292857141938},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.794651,
#   'pickup_longitude': -73.972048,
#   'distance_from_selected': 0.24257052855819514},
#  {'trip_distance': 4.9,
#   'pickup_latitude': 40.741907,
#   'pickup_longitude': -74.003545,
#   'distance_from_selected': 0.24259522030329075},
#  {'trip_distance': 0.96,
#   'pickup_latitude': 40.745847,
#   'pickup_longitude': -74.001817,
#   'distance_from_selected': 0.24262328688318888},
#  {'trip_distance': 1.39,
#   'pickup_latitude': 40.741912,
#   'pickup_longitude': -74.003578,
#   'distance_from_selected': 0.24262747014302266},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 40.79858,
#   'pickup_longitude': -73.969018,
#   'distance_from_selected': 0.24266081991949934},
#  {'trip_distance': 5.17,
#   'pickup_latitude': 40.798562,
#   'pickup_longitude': -73.969052,
#   'distance_from_selected': 0.24267575236929245},
#  {'trip_distance': 0.73,
#   'pickup_latitude': 40.797632,
#   'pickup_longitude': -73.969822,
#   'distance_from_selected': 0.24268643091033923},
#  {'trip_distance': 6.8,
#   'pickup_latitude': 40.796757,
#   'pickup_longitude': -73.970537,
#   'distance_from_selected': 0.242694577726818},
#  {'trip_distance': 3.1,
#   'pickup_latitude': 40.755857,
#   'pickup_longitude': -73.997045,
#   'distance_from_selected': 0.2426976363997004},
#  {'trip_distance': 6.01,
#   'pickup_latitude': 40.715387,
#   'pickup_longitude': -74.013518,
#   'distance_from_selected': 0.2427974979957655},
#  {'trip_distance': 0.46,
#   'pickup_latitude': 40.800642,
#   'pickup_longitude': -73.967692,
#   'distance_from_selected': 0.2429515648601633},
#  {'trip_distance': 0.5,
#   'pickup_latitude': 40.800219,
#   'pickup_longitude': -73.968098,
#   'distance_from_selected': 0.2429929981398639},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.759445,
#   'pickup_longitude': -73.995501,
#   'distance_from_selected': 0.24299444073065377},
#  {'trip_distance': 0.87,
#   'pickup_latitude': 40.739887,
#   'pickup_longitude': -74.004942,
#   'distance_from_selected': 0.24308085048601005},
#  {'trip_distance': 4.0,
#   'pickup_latitude': 40.716232,
#   'pickup_longitude': -74.013591,
#   'distance_from_selected': 0.24311363813040948},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.800479,
#   'pickup_longitude': -73.968083,
#   'distance_from_selected': 0.24314764158839683},
#  {'trip_distance': 0.81,
#   'pickup_latitude': 40.735872,
#   'pickup_longitude': -74.006705,
#   'distance_from_selected': 0.24317605957207233},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.742803,
#   'pickup_longitude': -74.004093,
#   'distance_from_selected': 0.2434562881052793},
#  {'trip_distance': 2.6,
#   'pickup_latitude': 40.742502,
#   'pickup_longitude': -74.00424,
#   'distance_from_selected': 0.24347019990955762},
#  {'trip_distance': 1.28,
#   'pickup_latitude': 40.757185,
#   'pickup_longitude': -73.99723,
#   'distance_from_selected': 0.24347132156581028},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.773538,
#   'pickup_longitude': -73.98794,
#   'distance_from_selected': 0.24348858783113372},
#  {'trip_distance': 1.28,
#   'pickup_latitude': 40.741672,
#   'pickup_longitude': -74.004627,
#   'distance_from_selected': 0.2434941039388868},
#  {'trip_distance': 3.63,
#   'pickup_latitude': 40.710822,
#   'pickup_longitude': -74.015592,
#   'distance_from_selected': 0.24350955543469066},
#  {'trip_distance': 4.5,
#   'pickup_latitude': 40.740018,
#   'pickup_longitude': -74.005399,
#   'distance_from_selected': 0.2435527351211643},
#  {'trip_distance': 0.76,
#   'pickup_latitude': 40.739812,
#   'pickup_longitude': -74.00549,
#   'distance_from_selected': 0.2435562507594482},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.788362,
#   'pickup_longitude': -73.978052,
#   'distance_from_selected': 0.24356914416239836},
#  {'trip_distance': 1.7,
#   'pickup_latitude': 40.741825,
#   'pickup_longitude': -74.004707,
#   'distance_from_selected': 0.24362830187398085},
#  {'trip_distance': 3.03,
#   'pickup_latitude': 40.785935,
#   'pickup_longitude': -73.979897,
#   'distance_from_selected': 0.24365110924024033},
#  {'trip_distance': 1.55,
#   'pickup_latitude': 40.790222,
#   'pickup_longitude': -73.976825,
#   'distance_from_selected': 0.24368225099297514},
#  {'trip_distance': 3.12,
#   'pickup_latitude': 40.742112,
#   'pickup_longitude': -74.004672,
#   'distance_from_selected': 0.2437104170280806},
#  {'trip_distance': 3.4,
#   'pickup_latitude': 40.741249,
#   'pickup_longitude': -74.005201,
#   'distance_from_selected': 0.24385373829818963},
#  {'trip_distance': 1.88,
#   'pickup_latitude': 40.781072,
#   'pickup_longitude': -73.983538,
#   'distance_from_selected': 0.24388360598449446},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.740732,
#   'pickup_longitude': -74.005513,
#   'distance_from_selected': 0.2439370540385343},
#  {'trip_distance': 1.27,
#   'pickup_latitude': 40.77908,
#   'pickup_longitude': -73.98498,
#   'distance_from_selected': 0.24398114066459864},
#  {'trip_distance': 4.87,
#   'pickup_latitude': 40.799892,
#   'pickup_longitude': -73.969787,
#   'distance_from_selected': 0.24408717166823812},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.740991,
#   'pickup_longitude': -74.005581,
#   'distance_from_selected': 0.24410134322040225},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.779515,
#   'pickup_longitude': -73.984852,
#   'distance_from_selected': 0.24411366292979952},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.778392,
#   'pickup_longitude': -73.985658,
#   'distance_from_selected': 0.24417128346306574},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.739945,
#   'pickup_longitude': -74.006124,
#   'distance_from_selected': 0.24419204061762775},
#  {'trip_distance': 5.14,
#   'pickup_latitude': 40.709355,
#   'pickup_longitude': -74.016717,
#   'distance_from_selected': 0.24420209809500365},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.77596,
#   'pickup_longitude': -73.98728,
#   'distance_from_selected': 0.24421858610679106},
#  {'trip_distance': 1.85,
#   'pickup_latitude': 40.777575,
#   'pickup_longitude': -73.986287,
#   'distance_from_selected': 0.24425390681420603},
#  {'trip_distance': 2.03,
#   'pickup_latitude': 40.774567,
#   'pickup_longitude': -73.988232,
#   'distance_from_selected': 0.24428089088792698},
#  {'trip_distance': 0.31,
#   'pickup_latitude': 40.741115,
#   'pickup_longitude': -74.00577,
#   'distance_from_selected': 0.2443238834518657},
#  {'trip_distance': 1.29,
#   'pickup_latitude': 40.739702,
#   'pickup_longitude': -74.006372,
#   'distance_from_selected': 0.2443262413822986},
#  {'trip_distance': 8.74,
#   'pickup_latitude': 40.803842,
#   'pickup_longitude': -73.966812,
#   'distance_from_selected': 0.24434470763248356},
#  {'trip_distance': 1.2,
#   'pickup_latitude': 40.774893,
#   'pickup_longitude': -73.988128,
#   'distance_from_selected': 0.2443658771043993},
#  {'trip_distance': 1.36,
#   'pickup_latitude': 40.774462,
#   'pickup_longitude': -73.988552,
#   'distance_from_selected': 0.24449660199683906},
#  {'trip_distance': 5.05,
#   'pickup_latitude': 40.71597,
#   'pickup_longitude': -74.015138,
#   'distance_from_selected': 0.24451696166932507},
#  {'trip_distance': 9.1,
#   'pickup_latitude': 40.71592,
#   'pickup_longitude': -74.015208,
#   'distance_from_selected': 0.24456944262111263},
#  {'trip_distance': 0.68,
#   'pickup_latitude': 40.80409,
#   'pickup_longitude': -73.966942,
#   'distance_from_selected': 0.24460473679796776},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.80307,
#   'pickup_longitude': -73.967911,
#   'distance_from_selected': 0.2446813387265179},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.770837,
#   'pickup_longitude': -73.991015,
#   'distance_from_selected': 0.24470550797643137},
#  {'trip_distance': 2.3,
#   'pickup_latitude': 40.774329,
#   'pickup_longitude': -73.988897,
#   'distance_from_selected': 0.24471900810929964},
#  {'trip_distance': 9.21,
#   'pickup_latitude': 40.76952,
#   'pickup_longitude': -73.99197,
#   'distance_from_selected': 0.2448525950444456},
#  {'trip_distance': 0.71,
#   'pickup_latitude': 40.750685,
#   'pickup_longitude': -74.002108,
#   'distance_from_selected': 0.24493646275923053},
#  {'trip_distance': 2.0,
#   'pickup_latitude': 40.774312,
#   'pickup_longitude': -73.989205,
#   'distance_from_selected': 0.24497155489770886},
#  {'trip_distance': 8.7,
#   'pickup_latitude': 40.749792,
#   'pickup_longitude': -74.00267,
#   'distance_from_selected': 0.24506033870049038},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.741453,
#   'pickup_longitude': -74.006441,
#   'distance_from_selected': 0.24507375430673795},
#  {'trip_distance': 1.24,
#   'pickup_latitude': 40.750117,
#   'pickup_longitude': -74.002532,
#   'distance_from_selected': 0.24507483765781238},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.714814,
#   'pickup_longitude': -74.016124,
#   'distance_from_selected': 0.24512888783658984},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.747897,
#   'pickup_longitude': -74.003746,
#   'distance_from_selected': 0.24523219581654615},
#  {'trip_distance': 0.75,
#   'pickup_latitude': 40.749207,
#   'pickup_longitude': -74.003233,
#   'distance_from_selected': 0.24532028448132598},
#  {'trip_distance': 1.27,
#   'pickup_latitude': 40.74787,
#   'pickup_longitude': -74.003975,
#   'distance_from_selected': 0.24542875753464571},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 40.765758,
#   'pickup_longitude': -73.994847,
#   'distance_from_selected': 0.24546143817919336},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.763352,
#   'pickup_longitude': -73.996385,
#   'distance_from_selected': 0.24563319862958757},
#  {'trip_distance': 2.27,
#   'pickup_latitude': 40.74805,
#   'pickup_longitude': -74.00412,
#   'distance_from_selected': 0.24563587787617974},
#  {'trip_distance': 1.98,
#   'pickup_latitude': 40.739142,
#   'pickup_longitude': -74.00807,
#   'distance_from_selected': 0.2456771977697632},
#  {'trip_distance': 1.66,
#   'pickup_latitude': 40.76306,
#   'pickup_longitude': -73.996785,
#   'distance_from_selected': 0.2458434016299874},
#  {'trip_distance': 2.46,
#   'pickup_latitude': 40.740622,
#   'pickup_longitude': -74.007735,
#   'distance_from_selected': 0.24593950810921045},
#  {'trip_distance': 1.17,
#   'pickup_latitude': 40.738767,
#   'pickup_longitude': -74.0086,
#   'distance_from_selected': 0.2460236334765476},
#  {'trip_distance': 1.76,
#   'pickup_latitude': 40.715947,
#   'pickup_longitude': -74.016737,
#   'distance_from_selected': 0.24604091208171963},
#  {'trip_distance': 4.59,
#   'pickup_latitude': 40.815817,
#   'pickup_longitude': -73.958397,
#   'distance_from_selected': 0.2461673474244785},
#  {'trip_distance': 2.48,
#   'pickup_latitude': 40.760477,
#   'pickup_longitude': -73.998625,
#   'distance_from_selected': 0.24623692410766426},
#  {'trip_distance': 2.1,
#   'pickup_latitude': 40.744341,
#   'pickup_longitude': -74.006568,
#   'distance_from_selected': 0.24634101551508203},
#  {'trip_distance': 3.05,
#   'pickup_latitude': 40.741972,
#   'pickup_longitude': -74.007642,
#   'distance_from_selected': 0.24638209023385366},
#  {'trip_distance': 0.7,
#   'pickup_latitude': 40.744275,
#   'pickup_longitude': -74.006706,
#   'distance_from_selected': 0.24644070353940967},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.758719,
#   'pickup_longitude': -74.000013,
#   'distance_from_selected': 0.2466481263054706},
#  {'trip_distance': 4.3,
#   'pickup_latitude': 40.748208,
#   'pickup_longitude': -74.005309,
#   'distance_from_selected': 0.24678171083976166},
#  {'trip_distance': 1.67,
#   'pickup_latitude': 40.780255,
#   'pickup_longitude': -73.9876,
#   'distance_from_selected': 0.2468161719276124},
#  {'trip_distance': 1.3,
#   'pickup_latitude': 40.742172,
#   'pickup_longitude': -74.00809,
#   'distance_from_selected': 0.24687264879690274},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.820267,
#   'pickup_longitude': -73.955068,
#   'distance_from_selected': 0.24692002238174326},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.821517,
#   'pickup_longitude': -73.954177,
#   'distance_from_selected': 0.24718439363762768},
#  {'trip_distance': 1.9,
#   'pickup_latitude': 40.752133,
#   'pickup_longitude': -74.004754,
#   'distance_from_selected': 0.24794832377937964},
#  {'trip_distance': 1.84,
#   'pickup_latitude': 40.75085,
#   'pickup_longitude': -74.00562,
#   'distance_from_selected': 0.2481796133851418},
#  {'trip_distance': 0.6,
#   'pickup_latitude': 40.745711,
#   'pickup_longitude': -74.008496,
#   'distance_from_selected': 0.24865824650913695},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 40.7472,
#   'pickup_longitude': -74.007947,
#   'distance_from_selected': 0.2487644735668702},
#  {'trip_distance': 1.5,
#   'pickup_latitude': 40.760528,
#   'pickup_longitude': -74.002757,
#   'distance_from_selected': 0.24991737013061496},
#  {'trip_distance': 1.6,
#   'pickup_latitude': 40.760434,
#   'pickup_longitude': -74.002849,
#   'distance_from_selected': 0.24995552351768432},
#  {'trip_distance': 0.9,
#   'pickup_latitude': 40.756054,
#   'pickup_longitude': -74.005378,
#   'distance_from_selected': 0.25022671336209934},
#  {'trip_distance': 1.0,
#   'pickup_latitude': 40.848462,
#   'pickup_longitude': -73.937645,
#   'distance_from_selected': 0.25669347441842233},
#  {'trip_distance': 1.8,
#   'pickup_latitude': 40.754176,
#   'pickup_longitude': -74.04442,
#   'distance_from_selected': 0.2850134654643588},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.690387,
#   'pickup_longitude': -74.177668,
#   'distance_from_selected': 0.3991082709403558},
#  {'trip_distance': 1.95,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 5.19,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 2.8,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 0.3,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 1.1,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 1.33,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 0.1,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 1.18,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 3.2,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 10.4,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 1.09,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 9.7,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 0.0,
#   'pickup_longitude': 0.0,
#   'distance_from_selected': 84.23581962219279}]

# %% [markdown]
# Ok great! Now that we can provide a new trip location, and find the distances of the three nearest trips, we can take  calculate an estimate of the trip distance for that new trip location.
#
# We do so simply by calculating the average of it's nearest neighbors.

# %%
import statistics
def mean_distance(neighbors):
    nearest_distances = list(map(lambda neighbor: neighbor['trip_distance'], neighbors))
    return round(statistics.mean(nearest_distances), 3)

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
distance_estimate_of_selected_trip = mean_distance(nearest_three_neighbors) # 12.593
distance_estimate_of_selected_trip

# %% [markdown]
# ### Choosing the correct number of neighbors

# %% [markdown]
# Now, as we know from the last lesson, one tricky element is to determine how many neighbors to choose, our $k$ value,  before calculating the average.  We want to choose our value of $k$ such that it properly matches actual data, and so that it applies to new data.  There are fancy formulas to ensure that we **train** our algorithm so that our formula is optimized for all data, but here let's see different $k$ values manually.  This is the gist of choosing our $k$ value:
#
# * If we choose a $k$ value too low, our formula will be too heavily influenced by a single neighbor, whereas if our $k$ value is too high, we will be choosing so many neighbors that our nearest neighbors formula will not be adjust enough according to locations.
#
# Ok, let's experiment with this.

# %% [markdown]
# First, let's choose a midtown location, to see what the trip distance would be.  A Google search reveals the coordinates of 51st and 7th avenue to be the following.

# %%
midtown_trip = dict(pickup_latitude=40.761710, pickup_longitude=-73.982760)

# %%
seven_closest = nearest_neighbors(midtown_trip, cleaned_trips, number = 7)
seven_closest

# %% [markdown]
# Looking at the `distance_from_selected` it appears that our our trips are still fairly close to our selected trip.  Notice that most of the data is within a distance of .002 away, so going to the top 7 nearest neighbors didn't seem to give us neighbors too far from each other, which is a good sign.
#
# Still, it's hard to know what distance in latitude and longitude really look like, so let's map the data.

# %%
midtown_location = location(midtown_trip) # [40.76171, -73.98276]
midtown_map = map_from(midtown_location, 16)
closest_markers = markers_from_trips(seven_closest)

add_markers(closest_markers, midtown_map)

# %% [markdown]
# Ok.  These locations stay fairly close to our estimated location of 51st street and 7th Avenue.  So they could be a good estimate of a trip distance.

# %%
mean_distance(seven_closest) # 1.26

# %% [markdown]
# Ok, now let's try a different location

# %%
charging_bull_closest = nearest_neighbors({'pickup_latitude': 40.7049, 'pickup_longitude': -74.0137}, cleaned_trips, number = 12)

# %%
mean_distance(charging_bull_closest) # 3.515

# %% [markdown]
# Ok, so there appears to be a significant difference between choosing a location near Times Square versus choosing a location at Wall Street.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, we used the nearest neighbors function to predict the length of a taxi ride.  To do so, we selected a location, then found a number of taxi rides closest to that location, and finally took the average trip lengths of the nearest taxi rides to find an estimate of the new ride's trip length.  You can see that even with just a little bit of math and programming we can begin to make meaningful predictions with data.
